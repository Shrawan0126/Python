# %%
import sqlite3

# %%
## connect to an SQLite database
connection = sqlite3.connect('example.db')
connection

# %%
cursor = connection.cursor()

# %%
## create a table
cursor.execute('''
create Table if not exists employees (
    id INTEGER PRIMARY KEY,
    name TEXT NOT NULL,
    age INTEGER NOT NULL,
    department TEXT NOT NULL
)
''')
## Commit the changes to the database
connection.commit()

# %%
cursor.execute('''
Select * from employees
''')

# %%
## Insert the data in sqlite table
cursor.execute('''
Insert into employees (name, age, department)
               values ('John Doe', 30, 'Engineering')
''')

cursor.execute('''
Insert into employees (name, age, department)
               values ('Bob', 30, 'Engineering')
''')

cursor.execute('''
Insert into employees (name, age, department)
               values ('Doe', 30, 'Engineering')
''')

## Commit the changes to the database
connection.commit()

# %%
## Query the data from the table
cursor.execute('Select * from employees')
rows = cursor.fetchall()

##print the queried data

for row in rows:
    print(row)
# Out:
# (1, 'John Doe', 30, 'Engineering')
# (2, 'John Doe', 30, 'Engineering')
# (3, 'Bob', 30, 'Engineering')
# (4, 'Doe', 30, 'Engineering')
# (5, 'John Doe', 30, 'Engineering')
# (6, 'Bob', 30, 'Engineering')
# (7, 'Doe', 30, 'Engineering')

# %%
## create a new directory
import os
new_directory = "my_new_directory"
os.mkdir(new_directory)
print(f"Directory {new_directory} created successfully.")
# Out:
# Directory my_new_directory created successfully.

# %%
## listing files and Directories
items = os.listdir()
print(items)
# Out:
# ['binary_file.ipynb', 'destination.txt', 'example.bin', 'example.txt', 'fileoperation.ipynb', 'file_path.ipynb', 'my_new_directory']

# %%
### Joining paths
dir_name = "folder"
file_name = "file.txt"
full_path = os.path.join(dir_name, file_name)
print(full_path)
# Out:
# folder\file.txt

# %%
### Joining paths
dir_name = "folder"
file_name = "file.txt"
full_path = os.path.join(os.getcwd(), dir_name, file_name)
print(full_path)
# Out:
# d:\AI and ML\Python\file_handling\folder\file.txt

# %%
## file existence check
path = 'example1.txt'
if os.path.exists(path):
    print(f"The file '{path}' exists.")
else:
    print(f"The file '{path}' does not exist.")
# Out:
# The file 'example1.txt' does not exist.

# %%
### checking if a path is a file or directory
path = 'my_new_directory'
if os.path.isfile(path):
    print(f"{path} is a file.")
elif os.path.isdir(path):
    print(f"{path} is a directory.")
else:
    print(f"{path} is neither a file nor a directory.")
# Out:
# my_new_directory is a directory.

# %%
### getting the absolute path
relative_path = 'my_new_directory'
absolute_path = os.path.abspath(relative_path)
print(absolute_path)
# Out:
# d:\AI and ML\Python\file_handling\my_new_directory

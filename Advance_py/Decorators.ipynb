# %% [markdown]
# A decorator is a function that modifies another function’s behavior without changing its code.

# %%
## function copy
def welcome():
    return "Welcome to the advanced python course"

welcome()
# Out:
# 'Welcome to the advanced python course'

# %%
wel = welcome
print(wel())
del welcome
# Out:
# Welcome to the advanced python course

# %%
print(welcome())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 print(welcome())
#
# NameError: name 'welcome' is not defined

# %%
print(wel())
# Out:
# Welcome to the advanced python course

# %%
## Closures function
## Closures are useful when you want a function to remember some data without using global variables.
def main_welcome(msg):
    def sub_welcome_method():
        print("Welcome to the advance python course")
        print(msg)
        print("Please learn these concept properly")
    return sub_welcome_method()

# %%
main_welcome("Welcome broooo")
# Out:
# Welcome to the advance python course
# Welcome broooo
# Please learn these concept properly

# %%
def main_welcome(func):
    def sub_welcome_method():
        print("Welcome to the advance python course")
        func("Hello sir,Good Morning")
        print("Please learn these concept properly")
    return sub_welcome_method()

# %%
main_welcome(print)
# Out:
# Welcome to the advance python course
# Hello sir,Good Morning
# Please learn these concept properly

# %%
def main_welcome(func,lst):
    def sub_welcome_method():
        print("Welcome to the advance python course")
        print(func(lst))
        print("Please learn these concept properly")
    return sub_welcome_method()

# %%
main_welcome(len,[1,2,3,4,5])
# Out:
# Welcome to the advance python course
# 5
# Please learn these concept properly

# %%
### Decorator 
def main_welcome(func):
    def sub_welcome_method():
        print("Welcome to the advance python course")
        func()
        print("Please learn these concept properly")
    return sub_welcome_method()

# %%
def course_introduction():
    print("This is an advanced python course")

course_introduction()
# Out:
# This is an advanced python course

# %%
main_welcome(course_introduction) 
## without calling main_welcomme function, print all of this
# Out:
# Welcome to the advance python course
# This is an advanced python course
# Please learn these concept properly

# %%
@main_welcome
def course_introduction():
    print("This is an advanced python course")
# Out:
# Welcome to the advance python course
# This is an advanced python course
# Please learn these concept properly

# %%
### Decorator
def my_decorator(func):
    def wrapper():
        print("Something is happening before the function is called")
        func()
        print("Somthing is happening after the function is called")
    return wrapper

# %%
@my_decorator
def say_hello():
    print("Hello! ")

# %%
say_hello()
# Out:
# Something is happening before the function is called
# Hello!
# Somthing is happening after the function is called

# %%
## Decorators with arguments
def repeat(n):
    def decorator(func):
        def wrapper(*args, **kwargs):
            for _ in range(n):
                func(*args, **kwargs)
        return wrapper
    return decorator

# %%
@repeat(6)
def say_hello():
    print("Hello")

# %%
say_hello()
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello

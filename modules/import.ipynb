# %%
from math import sqrt,pi
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
from package.maths import addition
addition(5, 10)
# Out:
# 15

# %%
from package import maths
maths.addition(5, 10)
# Out:
# 15

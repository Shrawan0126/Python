# %%
 ### INheritance
## paret class
class Car:
    def __init__ (self, winddows, doors, enginetype):
        self.windows = winddows
        self.doors = doors
        self.enginetype = enginetype

    def drive(self):
        print(f"The person is driving a {self.enginetype} car with {self.windows} windows and {self.doors} doors.")

car1 = Car(4, 4, "gasoline")
car1.drive()
# Out:
# The person is driving a gasoline car with 4 windows and 4 doors.

# %%
class Tesla(Car):
    def __init__(self, windows, doors, enginetype, is_selfdriving):
        super().__init__(windows, doors, enginetype)
        self.is_selfdriving = is_selfdriving

    def selfdriving(self):
        print(f"The person is driving a {self.enginetype} Tesla with {self.windows} windows and {self.doors} doors. Self-driving: {self.is_selfdriving  }")


tesla1 = Tesla(4, 4, "electric", True)
tesla1.selfdriving()
tesla1.drive()
# Out:
# The person is driving a electric Tesla with 4 windows and 4 doors. Self-driving: True
# The person is driving a electric car with 4 windows and 4 doors.

# %%
### Multiple Inheritance : when a class inherits from more than one parent class
## Base class 1
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        print("subclass must implement this method")
    

## Base class 2
class Pet:
    def __init__(self, owner):
        self.owner = owner

## Derived class
class Dog(Animal, Pet):
    def __init__(self, name, owner, breed):
        Animal.__init__(self, name)
        Pet.__init__(self, owner)
        self.breed = breed

    def speak(self):
        print(f"{self.name} says Woof! I am a {self.breed} owned by {self.owner}.")

### Create an object
dog = Dog("Buddy", "Alice", "Golden Retriever")
print(dog.speak()  )
# Out:
# Buddy says Woof! I am a Golden Retriever owned by Alice.
# None
